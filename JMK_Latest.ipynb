# %%
print('Jai Maa Kali')
# Out:
# Jai Maa Kali

# %%
from selenium.webdriver.common.by import By

# %%
from selenium import webdriver

# %%
url='https://www.adamchoi.co.uk/teamgoals/detailed'

# %%
path='C:\\Users\\barad\\Downloads\\jup_latest\\colabs\\Selenium\\chromedriver.exe'

# %%
import time

# %%
driver=webdriver.Chrome()
driver.get(url)
time.sleep(5)

# %%
#driver.quit()

# %%
c=driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')#Xpath
c.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 c=driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')#Xpath
# ----> 2 c.click()
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %%
m=driver.find_elements(By.TAG_NAME, 'tr')

# %%
for i in m:
    print(i.text)
# Out:
# 17-08-2024 Arsenal 2 - 0 Wolves
# 24-08-2024 Aston Villa 0 - 2 Arsenal
# 31-08-2024 Arsenal 1 - 1 Brighton
# 15-09-2024 Tottenham 0 - 1 Arsenal
# 22-09-2024 Man City 2 - 2 Arsenal
# 28-09-2024 Arsenal 4 - 2 Leicester
# 05-10-2024 Arsenal 3 - 1 Southampton
# 19-10-2024 Bournemouth 2 - 0 Arsenal
# 27-10-2024 Arsenal 2 - 2 Liverpool
# 02-11-2024 Newcastle 1 - 0 Arsenal
# 10-11-2024 Chelsea 1 - 1 Arsenal
# 23-11-2024 Arsenal 3 - 0 Nott'm Forest
# 30-11-2024 West Ham 2 - 5 Arsenal
# 04-12-2024 Arsenal 2 - 0 Man United
# 08-12-2024 Fulham 1 - 1 Arsenal
# 14-12-2024 Arsenal 0 - 0 Everton
# 21-12-2024 Crystal Palace 1 - 5 Arsenal
# Next match: 28-12-2024 Arsenal vs Ipswich
# 17-08-2024 West Ham 1 - 2 Aston Villa
# 24-08-2024 Aston Villa 0 - 2 Arsenal
# 31-08-2024 Leicester 1 - 2 Aston Villa
# 14-09-2024 Aston Villa 3 - 2 Everton
# 21-09-2024 Aston Villa 3 - 1 Wolves
# 29-09-2024 Ipswich 2 - 2 Aston Villa
# 06-10-2024 Aston Villa 0 - 0 Man United
# 19-10-2024 Fulham 1 - 3 Aston Villa
# ...

# %%
date=[]
ht=[]
s=[]
aw=[]

# %%
for i in m:
    date.append(i.find_element(By.XPATH,'./td[1]').text)
    ht.append(i.find_element(By.XPATH,'./td[1]').text)
    s.append(i.find_element(By.XPATH,'./td[1]').text)
    aw.append(i.find_element(By.XPATH,'./td[1]').text)

# %%
date
# Out:
# ['17-08-2024',
#  '24-08-2024',
#  '31-08-2024',
#  '15-09-2024',
#  '22-09-2024',
#  '28-09-2024',
#  '05-10-2024',
#  '19-10-2024',
#  '27-10-2024',
#  '02-11-2024',
#  '10-11-2024',
#  '23-11-2024',
#  '30-11-2024',
#  '04-12-2024',
#  '08-12-2024',
#  '14-12-2024',
#  '21-12-2024',
#  'Next match: 28-12-2024 Arsenal vs Ipswich',
#  '17-08-2024',
#  '24-08-2024',
#  '31-08-2024',
#  '14-09-2024',
#  '21-09-2024',
#  '29-09-2024',
#  '06-10-2024',
#  '19-10-2024',
#  '26-10-2024',
#  '03-11-2024',
#  '09-11-2024',
#  '23-11-2024',
#  '01-12-2024',
#  '04-12-2024',
#  '07-12-2024',
#  '14-12-2024',
#  '21-12-2024',
#  '26-12-2024',
#  '17-08-2024',
#  '25-08-2024',
#  '31-08-2024',
#  '14-09-2024',
#  '21-09-2024',
#  '30-09-2024',
#  '05-10-2024',
#  '19-10-2024',
#  '26-10-2024',
#  '02-11-2024',
#  '09-11-2024',
#  '23-11-2024',
#  '30-11-2024',
#  '05-12-2024',
#  '08-12-2024',
#  '16-12-2024',
#  '22-12-2024',
#  '26-12-2024',
#  'Next match: 29-12-2024 Fulham vs Bournemouth',
# ...

# %%
import pandas as pd

# %%
#selecting elements withindropdown

# %%
from selenium.webdriver.support.ui import Select

# %%
d=Select(driver.find_element(By.ID,'country'))
d.select_by_visible_text('Spain')

# %%
#MNREGA
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# %%
url='https://mnregaweb2.nic.in/netnrega/dynamic_account_details_ippe.aspx'

# %%
c=webdriver.Chrome()
c.get(url)
time.sleep(5)

# %%
d=driver.find_element(By.ID, 'ddl_state')
select = Select(d)
select.select_by_index(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 d=driver.find_element(By.ID, 'ddl_state')
#       2 select = Select(d)
#       3 select.select_by_index(1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

# Start a new browser session (Make sure the browser window is open)
#driver = webdriver.Chrome()

# Open the page containing the dropdown
driver.get("https://mnregaweb2.nic.in/netnrega/dynamic_account_details_ippe.aspx")  # Replace with your URL

# Make sure the window is open and active before proceeding
if driver.current_window_handle:
    # Find the dropdown element by ID (replace 'ddl_state' with your actual element's ID)
    dropdown = driver.find_element(By.ID, 'ddl_state')
    select = Select(dropdown)
    select.select_by_index(2)
    time.sleep(2)

# %%
dropdown = driver.find_element(By.ID, 'ddl_dist')
select = Select(dropdown)
select.select_by_index(2)
time.sleep(2)

# %%
dropdown = driver.find_element(By.ID, 'ddl_blk')
select = Select(dropdown)
select.select_by_index(2)
time.sleep(2)

# %%
dropdown = driver.find_element(By.ID, 'ddl_pan')
select = Select(dropdown)
select.select_by_index(2)
time.sleep(2)

# %%
d=driver.find_element(By.XPATH,"//input[@name='Button1']")
d.click()

# %%
m=driver.find_elements(By.TAG_NAME, 'table')

# %%
download_folder = r"C:\\Users\\barad\\OneDrive\\Desktop\\MNREGA" 
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()
chrome_options.add_argument("--headless")  # Optional: Run Chrome in headless mode
chrome_options.add_experimental_option("prefs", {
    "download.default_directory": download_folder,  # Set the download folder path
    "download.prompt_for_download": False,  # Disable the download prompt
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True  # Optional: Disable safe browsing
})

# %%
driver = webdriver.Chrome(options=chrome_options)

# %%
download_button = driver.find_element(By.XPATH, '//a[@id="LinkButton1"]')  # Replace with the actual button locator
download_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 download_button = driver.find_element(By.XPATH, '//a[@id="LinkButton1"]')  # Replace with the actual button locator
#       2 download_button.click()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# ...

# %%
# Set the download folder path
download_folder = r"C:\\Users\\barad\\OneDrive\\Desktop\\MNREGA"  # Specify the folder path where you want to save the file

# Set Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Optional: Run Chrome in headless mode
chrome_options.add_experimental_option("prefs", {
    "download.default_directory": download_folder,  # Set the download folder path
    "download.prompt_for_download": False,  # Disable the download prompt
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True  # Optional: Disable safe browsing
})

# Initialize WebDriver with the Chrome options
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the page with the download button
driver.get("https://mnregaweb2.nic.in/netnrega/dynamic_account_details_ippe.aspx")  # Replace with the actual URL
